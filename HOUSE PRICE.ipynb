# %% [markdown]
# # Import libararies

# %%
import pandas as pd
import numpy as np
import matplotlib as lib
import seaborn as sns
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn import preprocessing
from sklearn.compose import ColumnTransformer

# %% [markdown]
# # Read files

# %%
data = pd.read_csv("house_price_train.csv")
data2= pd.read_csv("house_price_train.csv")
data3=pd.read_csv("house_price_train.csv")
test = pd.read_csv("house_price_test.csv")

print(len(test.columns))
print(len(data.columns))
print(test.shape)
print(data.shape)
# Out:
# 80
# 81
# (1459, 80)
# (1460, 81)

# %%
data.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %% [markdown]
# # information

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
data.shape
# Out:
# (1460, 81)

# %%
len(data)
# Out:
# 1460

# %% [markdown]
# # cleaning data

# %%
print(len(test.columns))
print(len(data.columns))
print(test.shape)
print(data.shape)
# Out:
# 80
# 81
# (1459, 80)
# (1460, 81)

# %%
na_percentage = data.isna().mean() * 100

# Drop columns with NaN percentage greater than 70%
columns_to_drop = na_percentage[na_percentage > 11].index
new_data = data.drop(columns_to_drop, axis=1,inplace=True)

# %% [markdown]
# ## drop duplicates

# %%
df_t1= data.T
df_t2= data2.T

# %%
df_t1.drop_duplicates()
df_t2.drop_duplicates()# in column
# Out:
#                  0       1       2        3       4       5       6     \
# Id                  1       2       3        4       5       6       7
# MSSubClass         60      20      60       70      60      50      20
# MSZoning           RL      RL      RL       RL      RL      RL      RL
# LotArea          8450    9600   11250     9550   14260   14115   10084
# Street           Pave    Pave    Pave     Pave    Pave    Pave    Pave
# ...               ...     ...     ...      ...     ...     ...     ...
# MoSold              2       5       9        2      12      10       8
# YrSold           2008    2007    2008     2006    2008    2009    2007
# SaleType           WD      WD      WD       WD      WD      WD      WD
# SaleCondition  Normal  Normal  Normal  Abnorml  Normal  Normal  Normal
# SalePrice      208500  181500  223500   140000  250000  143000  307000
#
#                  7        8       9     ...    1450     1451    1452     1453  \
# ...

# %%
data=df_t1.T # data after drop duplicates
data2=df_t2.T
data3=data2

# %% [markdown]
# ## fill nan value

# %%
numerical_columns = data.select_dtypes(include=[np.number])
data[numerical_columns.columns] = numerical_columns.fillna(0)

numerical_columns = test.select_dtypes(include=[np.number])
test[numerical_columns.columns] = numerical_columns.fillna(0)

numerical_columns = data2.select_dtypes(include=[np.number])
data2[numerical_columns.columns] = numerical_columns.fillna(0)
data2.isna().any().sum()
# Out:
# 0

# %%
categorical_columns = data.select_dtypes(include=['object'])
data[categorical_columns.columns] = categorical_columns.fillna('Unknown')
categorical_columns = test.select_dtypes(include=['object'])
test[categorical_columns.columns] = categorical_columns.fillna('Unknown')
categorical_columns = data2.select_dtypes(include=['object'])
data2[categorical_columns.columns] = categorical_columns.fillna('Unknown')

# %%
data.isna().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 81, dtype: int64

# %%
test.isna().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MiscVal          0
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# Length: 80, dtype: int64

# %% [markdown]
# ## data after cleaning

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          1460 non-null   object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
cate_columns = data.select_dtypes(include=['object'])

numerical_columns = data.select_dtypes(include=['int64','float64'])

cata_columns_list= list(cate_columns.columns)
numerical_columns_list = list(numerical_columns.columns)

# %%
cata_columns_list
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
numerical_columns_list
# Out:
# ['Id',
#  'MSSubClass',
#  'LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'SalePrice']

# %% [markdown]
# # one hot encoder

# %%
print(len(test.columns))
print(len(data.columns))
print(test.shape)
print(data.shape)
# Out:
# 80
# 81
# (1459, 80)
# (1460, 81)

# %%
one_hot = OneHotEncoder()
transformer=ColumnTransformer([('one_hot',one_hot,cata_columns_list)],remainder='passthrough')

# %%
transform = transformer.fit_transform(data)

# %%
dummies=pd.get_dummies(data,columns=cata_columns_list)

# %%
transformer2=ColumnTransformer([('one_hot',one_hot,cata_columns_list)],remainder='passthrough')
# cata_test = list(test.select_dtypes('object').columns)
transform2 = transformer2.fit_transform(test)
dummies2=pd.get_dummies(test,columns=cata_columns_list)

# %%
print(len(dummies2.columns))
print(len(x_test.columns))
# Out:
# 293
# 216

# %%
dummies= dummies

# %%
dummies.shape
# Out:
# (1460, 306)

# %%
dummies.dtypes
# Out:
# Id                       int64
# MSSubClass               int64
# LotArea                  int64
# OverallQual              int64
# OverallCond              int64
#                          ...
# SaleCondition_AdjLand    uint8
# SaleCondition_Alloca     uint8
# SaleCondition_Family     uint8
# SaleCondition_Normal     uint8
# SaleCondition_Partial    uint8
# Length: 217, dtype: object

# %%
y=dummies['SalePrice']

# %%
x=dummies.drop('SalePrice',axis=1)

# %%
x_t = dummies2

# %% [markdown]
# ## modeling after one hot

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
model= RandomForestRegressor()

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
model.score(x_test,y_test)
# Out:
# 0.8348804570596557

# %%
y_p = model.predict(x_t)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[133], line 1
# ----> 1 y_p = model.predict(x_t)
#
# File ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:981, in ForestRegressor.predict(self, X)
#     979 check_is_fitted(self)
#     980 # Check data
# --> 981 X = self._validate_X_predict(X)
#     983 # Assign chunk of trees to jobs
#     984 n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# File ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:602, in BaseForest._validate_X_predict(self, X)
#     599 """
#     600 Validate X whenever one tries to predict, apply, predict_proba."""
#     601 check_is_fitted(self)
# --> 602 X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#     603 if issparse(X) and (X.indices.dtype != np.intc or X.indptr.dtype != np.intc):
# ...

# %%
y_test[:10]
# Out:
# 1180    250000
# 289     153575
# 22      230000
# 840     140000
# 658      97500
# 210      98000
# 921     145900
# 796     143500
# 1091    160000
# 706     302000
# Name: SalePrice, dtype: int64

# %% [markdown]
# ## label encoder

# %%
print(len(test.columns))
print(len(data2.columns))
print(test.shape)
print(data2.shape)
# Out:
# 80
# 81
# (1459, 80)
# (1460, 81)

# %%
label_encoder = preprocessing.LabelEncoder()
for column in data2.columns:
    # Check if the column contains categorical data
    if data2[column].dtype == 'object':
        # Fit the LabelEncoder on the column and transform the labels
        data2[column] = label_encoder.fit_transform(data[column])

# %%
label_encoder = preprocessing.LabelEncoder()
for column in test.columns:
    # Check if the column contains categorical data
    if test[column].dtype == 'object':
        # Fit the LabelEncoder on the column and transform the labels
        test[column] = label_encoder.fit_transform(test[column])

# %%
test
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0     1461          20         2         80.0    11622       1      2
# 1     1462          20         3         81.0    14267       1      2
# 2     1463          60         3         74.0    13830       1      2
# 3     1464          60         3         78.0     9978       1      2
# 4     1465         120         3         43.0     5005       1      2
# ...    ...         ...       ...          ...      ...     ...    ...
# 1454  2915         160         4         21.0     1936       1      2
# 1455  2916         160         4         21.0     1894       1      2
# 1456  2917          20         3        160.0    20000       1      2
# 1457  2918          85         3         62.0    10441       1      2
# 1458  2919          60         3         74.0     9627       1      2
#
#       LotShape  LandContour  Utilities  ...  ScreenPorch  PoolArea  PoolQC  \
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 62 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int32
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   int32
#  5   LotShape       1460 non-null   int32
#  6   LandContour    1460 non-null   int32
#  7   Utilities      1460 non-null   int32
#  8   LotConfig      1460 non-null   int32
#  9   LandSlope      1460 non-null   int32
#  10  Neighborhood   1460 non-null   int32
#  11  Condition1     1460 non-null   int32
#  12  Condition2     1460 non-null   int32
#  13  BldgType       1460 non-null   int32
#  14  HouseStyle     1460 non-null   int32
#  15  OverallQual    1460 non-null   int64
#  16  OverallCond    1460 non-null   int64
#  17  YearBuilt      1460 non-null   int64
# ...

# %% [markdown]
# ## modeling label encoder

# %%
x2=data2.drop('SalePrice',axis=1)
y2=data2['SalePrice']
x_train2,x_test2,y_train2,y_test2 = train_test_split(x2,y2,test_size=0.2)

# %%
model.fit(x_train2,y_train2)
# Out:
# RandomForestRegressor()

# %%
model.score(x_test2,y_test2)
# Out:
# 0.9093783554791137

# %%
y_p = model.predict(test)

# %%
sub = pd.read_csv("sample_submission.csv")
sub
# Out:
#         Id      SalePrice
# 0     1461  169277.052498
# 1     1462  187758.393989
# 2     1463  183583.683570
# 3     1464  179317.477511
# 4     1465  150730.079977
# ...    ...            ...
# 1454  2915  167081.220949
# 1455  2916  164788.778231
# 1456  2917  219222.423400
# 1457  2918  184924.279659
# 1458  2919  187741.866657
#
# [1459 rows x 2 columns]

# %%
test_ids = sub['Id']
submission_preds=y_p
output = pd.DataFrame({"Id":test_ids.values,"SalePrice":submission_preds})
output.to_csv(f'model_ensemble_v1_submission.csv', index=False)

# %%
np.random.seed()
for i in range(10,101,10):
    print('n_estamator: ',i)
    model2=RandomForestRegressor(n_estimators=i).fit(x_train2,y_train2)
    print(f'model accuracy on test:{model2.score(x_test2,y_test2)*100:0.2f} ','%')
    print(' ')
# Out:
# n_estamator:  10
# model accuracy on test:89.56  %
#
# n_estamator:  20
# model accuracy on test:90.52  %
#
# n_estamator:  30
# model accuracy on test:90.75  %
#
# n_estamator:  40
# model accuracy on test:91.03  %
#
# n_estamator:  50
# model accuracy on test:90.52  %
#
# n_estamator:  60
# model accuracy on test:91.14  %
#
# n_estamator:  70
# model accuracy on test:90.88  %
#
# n_estamator:  80
# model accuracy on test:90.91  %
#
# n_estamator:  90
# model accuracy on test:91.04  %
#
# n_estamator:  100
# model accuracy on test:90.67  %

# %%
data3.head()
# Out:
#    Id  MSSubClass  MSZoning  LotArea  Street  LotShape  LandContour  \
# 0   0           5         3      327       1         3            3
# 1   1           0         3      498       1         3            3
# 2   2           5         3      702       1         0            3
# 3   3           6         3      489       1         0            3
# 4   4           5         3      925       1         0            3
#
#    Utilities  LotConfig  LandSlope  ...  EnclosedPorch  3SsnPorch  \
# 0          0          4          0  ...              0          0
# 1          0          2          0  ...              0          0
# 2          0          4          0  ...              0          0
# 3          0          0          0  ...            108          0
# 4          0          2          0  ...              0          0
#
#    ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  SaleType  SaleCondition  \
# 0            0         0        0       1       2         8              4
# ...

# %%
data3['SaleCondition'].unique()
# Out:
# array([4, 0, 5, 1, 2, 3])

# %%
x=data3['SaleCondition']
y=data3['SalePrice']
y
# Out:
# 0       412
# 1       339
# 2       442
# 3       194
# 4       494
#        ...
# 1455    314
# 1456    415
# 1457    527
# 1458    199
# 1459    221
# Name: SalePrice, Length: 1460, dtype: int64

# %%
df = pd.DataFrame({'x':x,'y':y})

# %%
df
# Out:
#       x    y
# 0     4  412
# 1     4  339
# 2     4  442
# 3     0  194
# 4     4  494
# ...  ..  ...
# 1455  4  314
# 1456  4  415
# 1457  4  527
# 1458  4  199
# 1459  4  221
#
# [1460 rows x 2 columns]

# %%
y_p = model.predict(x_test2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 y_p = model.predict(x_test2)
#
# File ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:981, in ForestRegressor.predict(self, X)
#     979 check_is_fitted(self)
#     980 # Check data
# --> 981 X = self._validate_X_predict(X)
#     983 # Assign chunk of trees to jobs
#     984 n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# File ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:602, in BaseForest._validate_X_predict(self, X)
#     599 """
#     600 Validate X whenever one tries to predict, apply, predict_proba."""
#     601 check_is_fitted(self)
# --> 602 X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#     603 if issparse(X) and (X.indices.dtype != np.intc or X.indptr.dtype != np.intc):
# ...

# %%
t = test.drop(['id'],axis=1)

# %%
sub["Hardness"]=model.predict(t)
sub.to_csv('submission.csv',index=False)

# %%
test_ids = test['id']
submission_preds=model.predict(t)

# %%
df = pd.DataFrame({"ID_LAT_LON_YEAR_WEEK":test_ids.values,"emission":submission_preds})

# %%
df.to_csv('submission2.csv',index=False)

# %%
sub["Hardness"]=model.predict(t)
sub.to_csv('submission.csv',index=False)
